# %%
import pandas as pd
import numpy as np
from collections import Counter as c
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
import pickle

# %%
data=pd.read_csv("D:\BTech\Final Year project\YT\kidney_disease.csv")
data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\918563605.py:1: SyntaxWarning: invalid escape sequence '\B'
#   data=pd.read_csv("D:\BTech\Final Year project\YT\kidney_disease.csv")
#       id  age  bp     sg  al  su     rbc        pc         pcc          ba  \
# 0      0   48  80  1.020   1   0  normal    normal  notpresent  notpresent
# 1      1    7  50  1.020   4   0  normal    normal  notpresent  notpresent
# 2      2   62  80  1.010   2   3  normal    normal  notpresent  notpresent
# 3      3   48  70  1.005   4   0  normal  abnormal     present  notpresent
# 4      4   51  80  1.010   2   0  normal    normal  notpresent  notpresent
# ..   ...  ...  ..    ...  ..  ..     ...       ...         ...         ...
# 243  243   23  80  1.025   0   0  normal    normal  notpresent  notpresent
# 244  244   45  60  1.025   0   0  normal    normal     present  notpresent
# 245  245   57  80  1.020   0   0  normal    normal  notpresent  notpresent
# 246  246   51  80  1.020   0   0  normal    normal     present  notpresent
# 247  247   34  60  1.025   0   0  normal    normal  notpresent  notpresent
#
#      ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0    ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1    ...   38  6000  3.9   no   no   no  good   no   no            ckd
# 2    ...   31  7500  4.6   no  yes   no  poor   no  yes            ckd
# 3    ...   32  6700  4.4  yes   no   no  poor  yes  yes            ckd
# 4    ...   35  7300    5   no   no   no  good   no   no            ckd
# ..   ...  ...   ...  ...  ...  ...  ...   ...  ...  ...            ...
# 243  ...   44  7300  4.9  yes   no   no  good   no   no            ckd
# 244  ...   45  9400  6.4  yes  yes   no  good   no  yes            ckd
# 245  ...   48  9600  5.6  yes   no  yes  poor   no   no            ckd
# 246  ...   52  9900  5.2  yes   no  yes  good   no  yes            ckd
# 247  ...   41  7000  4.8   no   no   no  poor  yes  yes            ckd
#
# [248 rows x 26 columns]

# %%
data.drop(["id"],axis=1,inplace=True)

# %%
data
# Out:
#      age  bp     sg  al  su     rbc        pc         pcc          ba  bgr  \
# 0     48  80  1.020   1   0  normal    normal  notpresent  notpresent  121
# 1      7  50  1.020   4   0  normal    normal  notpresent  notpresent  423
# 2     62  80  1.010   2   3  normal    normal  notpresent  notpresent  117
# 3     48  70  1.005   4   0  normal  abnormal     present  notpresent  106
# 4     51  80  1.010   2   0  normal    normal  notpresent  notpresent   74
# ..   ...  ..    ...  ..  ..     ...       ...         ...         ...  ...
# 243   23  80  1.025   0   0  normal    normal  notpresent  notpresent  123
# 244   45  60  1.025   0   0  normal    normal     present  notpresent  100
# 245   57  80  1.020   0   0  normal    normal  notpresent  notpresent   94
# 246   51  80  1.020   0   0  normal    normal     present  notpresent   81
# 247   34  60  1.025   0   0  normal    normal  notpresent  notpresent  124
#
#      ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0    ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1    ...   38  6000  3.9   no   no   no  good   no   no            ckd
# 2    ...   31  7500  4.6   no  yes   no  poor   no  yes            ckd
# 3    ...   32  6700  4.4  yes   no   no  poor  yes  yes            ckd
# 4    ...   35  7300    5   no   no   no  good   no   no            ckd
# ..   ...  ...   ...  ...  ...  ...  ...   ...  ...  ...            ...
# 243  ...   44  7300  4.9  yes   no   no  good   no   no            ckd
# 244  ...   45  9400  6.4  yes  yes   no  good   no  yes            ckd
# 245  ...   48  9600  5.6  yes   no  yes  poor   no   no            ckd
# 246  ...   52  9900  5.2  yes   no  yes  good   no  yes            ckd
# 247  ...   41  7000  4.8   no   no   no  poor  yes  yes            ckd
#
# [248 rows x 25 columns]

# %%
data.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
data.columns=['age','blood_pressure','specific_gravity','albumin',
              'sugar','red_blood_cells','pus_cell','pus_cell_clumps','bacteria',
              'blood glucose random','blood_urea','serum_creatinine','sodium','potassium',
              'hemoglobin','packed_cell_volume','white_blood_cell_count','red_blood_cell_count',
              'hypertension','diabetesmellitus','coronary_artery_disease','appetite',
              'pedal_edema','anemia','class'] # manually giving the name  of the columns

# %%
data.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood glucose random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'hemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetesmellitus', 'coronary_artery_disease', 'appetite',
#        'pedal_edema', 'anemia', 'class'],
#       dtype='object')

# %%
data['class'].unique()
# Out:
# array(['ckd', 'ckd\t'], dtype=object)

# %%
data['class']=data['class'].replace("ckd\t","ckd")
data['class']
# Out:
# 0      ckd
# 1      ckd
# 2      ckd
# 3      ckd
# 4      ckd
#       ...
# 243    ckd
# 244    ckd
# 245    ckd
# 246    ckd
# 247    ckd
# Name: class, Length: 248, dtype: object

# %%
catcols=set(data.dtypes[data.dtypes=='O'].index.values)
print(catcols)
# Out:
# {'red_blood_cells', 'red_blood_cell_count', 'class', 'bacteria', 'appetite', 'pedal_edema', 'pus_cell_clumps', 'white_blood_cell_count', 'coronary_artery_disease', 'anemia', 'pus_cell', 'packed_cell_volume', 'diabetesmellitus', 'hypertension'}

# %%
for i in catcols:
  print("Columns :",i)
  print(c(data[i]))
  print('*'*120+'\n')
# Out:
# Columns : red_blood_cells
# Counter({'normal': 201, 'abnormal': 47})
# ************************************************************************************************************************
#
# Columns : red_blood_cell_count
# Counter({'5.2': 17, '4.5': 15, '4.9': 12, '4.7': 11, '3.9': 10, '4.8': 10, '5': 9, '3.4': 9, '4.6': 8, '3.7': 8, '3.8': 7, '6.1': 7, '4': 6, '4.3': 6, '4.2': 6, '5.6': 6, '5.8': 6, '5.5': 6, '5.3': 6, '5.9': 6, '4.4': 5, '3.2': 5, '4.1': 5, '5.4': 5, '3.6': 4, '6': 4, '6.2': 4, '5.1': 4, '6.4': 4, '5.7': 4, '3.5': 3, '3.3': 3, '3': 3, '6.3': 3, '6.5': 3, '2.6': 2, '2.8': 2, '2.5': 2, '3.1': 2, '2.1': 2, '2.9': 2, '2.7': 2, '2.3': 1, '8': 1, '2.4': 1, '\t': 1})
# ************************************************************************************************************************
#
# Columns : class
# Counter({'ckd': 248})
# ************************************************************************************************************************
#
# Columns : bacteria
# Counter({'notpresent': 226, 'present': 22})
# ************************************************************************************************************************
#
# Columns : appetite
# Counter({'good': 167, 'poor': 81})
# ************************************************************************************************************************
#
# Columns : pedal_edema
# Counter({'no': 173, 'yes': 75})
# ************************************************************************************************************************
#
# Columns : pus_cell_clumps
# Counter({'notpresent': 207, 'present': 41})
# ************************************************************************************************************************
#
# Columns : white_blood_cell_count
# Counter({'9800': 11, '9600': 9, '6700': 8, '6900': 8, '9200': 8, '7200': 7, '7000': 7, '7800': 6, '11000': 6, '9100': 6, '4300': 6, '9400': 6, '7500': 5, '8300': 5, '7900': 5, '8600': 5, '5600': 5, '10700': 5, '10200': 5, '5000': 5, '8100': 5, '6300': 4, '5500': 4, '5800': 4, '10400': 4, '10500': 4, '4700': 4, '7300': 3, '4500': 3, '6200': 3, '8400': 3, '7700': 3, '4200': 3, '9500': 3, '6000': 2, '3800': 2, '11400': 2, '5300': 2, '10300': 2, '6400': 2, '8500': 2, '14600': 2, '7100': 2, '13200': 2, '6800': 2, '6500': 2, '9000': 2, '8200': 2, '15200': 2, '12400': 2, '12800': 2, '8800': 2, '12100': 1, '12200': 1, '18900': 1, '21600': 1, '11300': 1, '\t6200': 1, '11800': 1, '12500': 1, '11900': 1, '12700': 1, '13600': 1, '14900': 1, '16300': 1, '\t8400': 1, '10900': 1, '2200': 1, '11200': 1, '19100': 1, ' ': 1, '12300': 1, '16700': 1, '2600': 1, '26400': 1, '7400': 1, '4900': 1, '8000': 1, '12000': 1, '15700': 1, '4100': 1, '5700': 1, '11500': 1, '5400': 1, '10800': 1, '9900': 1})
# ************************************************************************************************************************
#
# Columns : coronary_artery_disease
# Counter({'no': 213, 'yes': 33, '\tno': 2})
# ************************************************************************************************************************
#
# Columns : anemia
# Counter({'no': 189, 'yes': 59})
# ************************************************************************************************************************
#
# Columns : pus_cell
# Counter({'normal': 172, 'abnormal': 76})
# ************************************************************************************************************************
#
# Columns : packed_cell_volume
# Counter({'41': 18, '44': 12, '32': 12, '36': 12, '33': 12, '28': 12, '52': 12, '37': 11, '34': 11, '48': 11, '40': 10, '35': 9, '29': 9, '30': 9, '31': 8, '39': 7, '24': 7, '45': 7, '42': 7, '43': 7, '26': 6, '38': 5, '50': 5, '27': 3, '22': 3, '46': 3, '25': 3, '23': 2, '19': 2, '16': 1, '\t?': 1, '14': 1, '18': 1, '17': 1, '15': 1, '21': 1, '20': 1, '\t43': 1, '47': 1, '9': 1, '49': 1, '53': 1})
# ************************************************************************************************************************
#
# Columns : diabetesmellitus
# Counter({'yes': 132, 'no': 110, '\tno': 3, '\tyes': 2, ' yes': 1})
# ************************************************************************************************************************
#
# Columns : hypertension
# Counter({'yes': 145, 'no': 103})
# ************************************************************************************************************************

# %%
catcols.remove('red_blood_cell_count')
catcols.remove('packed_cell_volume')
catcols.remove('white_blood_cell_count')
print(catcols)
# Out:
# {'red_blood_cells', 'class', 'bacteria', 'appetite', 'pedal_edema', 'pus_cell_clumps', 'coronary_artery_disease', 'anemia', 'pus_cell', 'diabetesmellitus', 'hypertension'}

# %%
contcols=set(data.dtypes[data.dtypes!='O'].index.values)
print(contcols)
# Out:
# {'sugar', 'blood glucose random', 'serum_creatinine', 'sodium', 'hemoglobin', 'albumin', 'blood_urea', 'potassium', 'age', 'specific_gravity', 'blood_pressure'}

# %%
for i in contcols:
  print("Continuos columns :",i)
  print(c(data[i]))
  print('*'*120+'\n')
# Out:
# Continuos columns : sugar
# Counter({0: 187, 2: 18, 3: 14, 4: 13, 1: 13, 5: 3})
# ************************************************************************************************************************
#
# Continuos columns : blood glucose random
# Counter({93: 6, 100: 5, 99: 5, 123: 5, 107: 5, 140: 5, 121: 4, 117: 4, 92: 4, 124: 4, 104: 4, 122: 4, 139: 4, 70: 3, 76: 3, 95: 3, 171: 3, 91: 3, 150: 3, 129: 3, 219: 3, 94: 3, 172: 3, 118: 3, 214: 3, 131: 3, 103: 3, 106: 2, 74: 2, 490: 2, 208: 2, 98: 2, 114: 2, 108: 2, 204: 2, 207: 2, 144: 2, 253: 2, 141: 2, 112: 2, 360: 2, 163: 2, 133: 2, 
: 1, 47.0: 1, 217.0: 1, 88.0: 1, 118.0: 1, 50.1: 1, 71.0: 1, 21.0: 1, 219.0: 1, 166.0: 1, 208.0: 1, 176.0: 1, 145.0: 1, 165.0: 1, 322.0: 1, 235.0: 1, 76.0: 1, 42.0: 1, 44.0: 1, 41.0: 1, 113.0: 1, 1.5: 1, 146.0: 1, 133.0: 1, 137.0: 1, 67.0: 1, 115.0: 1, 223.0: 1, 98.6: 1, 158.0: 1, 94.0: 1, 74.0: 1, 150.0: 1, 61.0: 1, 57.0: 1, 95.0: 1, 191.0: 1, 93.0: 1, 241.0: 1, 64.0: 1, 79.0: 1, 215.0: 1, 309.0: 1})
# ************************************************************************************************************************
#
# Continuos columns : potassium
# Counter({4.9: 20, 5.0: 20, 4.7: 15, 4.0: 14, 3.5: 14, 4.2: 13, 3.8: 13, 4.1: 12, 3.9: 12, 4.4: 11, 4.5: 11, 4.3: 10, 4.8: 10, 3.7: 8, 4.6: 7, 3.4: 5, 5.2: 5, 3.6: 4, 5.7: 4, 5.3: 4, 3.2: 3, 5.5: 3, 2.9: 3, 5.4: 3, 6.3: 3, 2.5: 2, 5.8: 2, 5.9: 2, 5.6: 2, 3.0: 2, 6.5: 2, 6.4: 1, 6.6: 1, 39.0: 1, 7.6: 1, 47.0: 1, 5.1: 1, 2.8: 1, 2.7: 1, 3.3: 1})
# ************************************************************************************************************************
#
# Continuos columns : age
# Counter({60: 15, 65: 15, 48: 9, 50: 9, 54: 9, 62: 8, 45: 8, 59: 8, 68: 7, 61: 7, 70: 7, 56: 7, 73: 6, 72: 6, 46: 6, 67: 6, 55: 6, 64: 6, 34: 6, 63: 5, 47: 5, 69: 5, 76: 5, 71: 5, 57: 5, 53: 4, 51: 3, 40: 3, 75: 3, 8: 3, 66: 3, 52: 2, 21: 2, 42: 2, 35: 2, 5: 2, 74: 2, 17: 2, 41: 2, 80: 2, 7: 1, 24: 1, 82: 1, 11: 1, 15: 1, 44: 1, 26: 1, 38: 1, 58: 1, 12: 1, 43: 1, 39: 1, 81: 1, 14: 1, 27: 1, 83: 1, 30: 1, 4: 1, 3: 1, 6: 1, 32: 1, 49: 1, 90: 1, 78: 1, 19: 1, 2: 1, 33: 1, 36: 1, 37: 1, 23: 1})
# ************************************************************************************************************************
#
# Continuos columns : specific_gravity
# Counter({1.01: 84, 1.015: 75, 1.02: 51, 1.025: 31, 1.005: 7})
# ************************************************************************************************************************
#
# Continuos columns : blood_pressure
# Counter({70: 74, 80: 57, 90: 53, 60: 28, 100: 25, 50: 5, 110: 3, 140: 1, 180: 1, 120: 1})
# ************************************************************************************************************************

# %%
contcols.remove('specific_gravity')
contcols.remove('albumin')
contcols.remove('sugar')

# %%
print(contcols)
# Out:
# {'blood glucose random', 'serum_creatinine', 'sodium', 'hemoglobin', 'blood_urea', 'potassium', 'age', 'blood_pressure'}

# %%
contcols.add('red_blood_cell_count')
contcols.add('packed_cell_volume')
contcols.add('white_blood_cell_count')
print(contcols)
# Out:
# {'red_blood_cell_count', 'blood glucose random', 'serum_creatinine', 'sodium', 'hemoglobin', 'blood_urea', 'potassium', 'age', 'white_blood_cell_count', 'packed_cell_volume', 'blood_pressure'}

# %%
catcols.add('specific_gravity')
catcols.add('albumin')
catcols.add('sugar')
print(catcols)
# Out:
# {'red_blood_cells', 'sugar', 'class', 'bacteria', 'appetite', 'pedal_edema', 'albumin', 'pus_cell_clumps', 'coronary_artery_disease', 'anemia', 'pus_cell', 'specific_gravity', 'diabetesmellitus', 'hypertension'}

# %%
data['coronary_artery_disease']=data.coronary_artery_disease.replace('\tno','no')
c(data['coronary_artery_disease'])
# Out:
# Counter({'no': 215, 'yes': 33})

# %%
data['diabetesmellitus']=data.diabetesmellitus.replace(to_replace={'\tno':'no','\tyes':'yes',' yes':'yes'})
c(data['diabetesmellitus'])
# Out:
# Counter({'yes': 135, 'no': 113})

# %%
data.packed_cell_volume=pd.to_numeric(data.packed_cell_volume, errors='coerce')
data.white_blood_cell_count=pd.to_numeric(data.white_blood_cell_count, errors='coerce')
data.red_blood_cell_count=pd.to_numeric(data.red_blood_cell_count, errors='coerce')

# %%
data['blood glucose random'].fillna(data['blood glucose random'].mean(),inplace=True)
data['blood_pressure'].fillna(data['blood_pressure'].mean(),inplace=True)
data['blood_urea'].fillna(data['blood_urea'].mean(),inplace=True)
data['hemoglobin'].fillna(data['hemoglobin'].mean(),inplace=True)
data['packed_cell_volume'].fillna(data['packed_cell_volume'].mean(),inplace=True)
data['potassium'].fillna(data['potassium'].mean(),inplace=True)
data['red_blood_cell_count'].fillna(data['red_blood_cell_count'].mean(),inplace=True)
data['serum_creatinine'].fillna(data['serum_creatinine'].mean(),inplace=True)
data['sodium'].fillna(data['sodium'].mean(),inplace=True)
data['white_blood_cell_count'].fillna(data['white_blood_cell_count'].mean(),inplace=True)
# Out:
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\1131343703.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['blood glucose random'].fillna(data['blood glucose random'].mean(),inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\1131343703.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['blood_pressure'].fillna(data['blood_pressure'].mean(),inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\1131343703.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['blood_urea'].fillna(data['blood_urea'].mean(),inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\1131343703.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['hemoglobin'].fillna(data['hemoglobin'].mean(),inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\1131343703.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['packed_cell_volume'].fillna(data['packed_cell_volume'].mean(),inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\1131343703.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['potassium'].fillna(data['potassium'].mean(),inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\1131343703.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['red_blood_cell_count'].fillna(data['red_blood_cell_count'].mean(),inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\1131343703.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['serum_creatinine'].fillna(data['serum_creatinine'].mean(),inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\1131343703.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['sodium'].fillna(data['sodium'].mean(),inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\1131343703.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['white_blood_cell_count'].fillna(data['white_blood_cell_count'].mean(),inplace=True)

# %%
data['age'].fillna(data['age'].mode()[0],inplace=True)
data['hypertension'].fillna(data['hypertension'].mode()[0],inplace=True)
data['pus_cell_clumps'].fillna(data['pus_cell_clumps'].mode()[0],inplace=True)
data['appetite'].fillna(data['appetite'].mode()[0],inplace=True)
data['albumin'].fillna(data['albumin'].mode()[0],inplace=True)
data['pus_cell'].fillna(data['pus_cell'].mode()[0],inplace=True)
data['red_blood_cells'].fillna(data['red_blood_cells'].mode()[0],inplace=True)
data['coronary_artery_disease'].fillna(data['coronary_artery_disease'].mode()[0],inplace=True)
data['bacteria'].fillna(data['bacteria'].mode()[0],inplace=True)
data['anemia'].fillna(data['anemia'].mode()[0],inplace=True)
data['sugar'].fillna(data['sugar'].mode()[0],inplace=True)
data['diabetesmellitus'].fillna(data['diabetesmellitus'].mode()[0],inplace=True)
data['pedal_edema'].fillna(data['pedal_edema'].mode()[0],inplace=True)
data['pedal_edema'].fillna(data['pedal_edema'].mode()[0],inplace=True)
# Out:
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['age'].fillna(data['age'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['hypertension'].fillna(data['hypertension'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['pus_cell_clumps'].fillna(data['pus_cell_clumps'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['appetite'].fillna(data['appetite'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['albumin'].fillna(data['albumin'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['pus_cell'].fillna(data['pus_cell'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['red_blood_cells'].fillna(data['red_blood_cells'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['coronary_artery_disease'].fillna(data['coronary_artery_disease'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['bacteria'].fillna(data['bacteria'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['anemia'].fillna(data['anemia'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['sugar'].fillna(data['sugar'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['diabetesmellitus'].fillna(data['diabetesmellitus'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['pedal_edema'].fillna(data['pedal_edema'].mode()[0],inplace=True)
# C:\Users\Saptarshi\AppData\Local\Temp\ipykernel_9828\771321841.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['pedal_edema'].fillna(data['pedal_edema'].mode()[0],inplace=True)

# %%
for i in catcols:
  print("LABEL ENCODING OF:",i)
  LEi = LabelEncoder() # creating an object of LabelEncoder
  print(c(data[i])) #getting the classes values before transformation
  data[i] = LEi.fit_transform(data[i])# trannsforming our text classes to numerical values
  print(c(data[i])) #getting the classes values after transformation
  print("*"*100)
# Out:
# LABEL ENCODING OF: red_blood_cells
# Counter({'normal': 201, 'abnormal': 47})
# Counter({1: 201, 0: 47})
# ****************************************************************************************************
# LABEL ENCODING OF: sugar
# Counter({0: 187, 2: 18, 3: 14, 4: 13, 1: 13, 5: 3})
# Counter({0: 187, 2: 18, 3: 14, 4: 13, 1: 13, 5: 3})
# ****************************************************************************************************
# LABEL ENCODING OF: class
# Counter({'ckd': 248})
# Counter({0: 248})
# ****************************************************************************************************
# LABEL ENCODING OF: bacteria
# Counter({'notpresent': 226, 'present': 22})
# Counter({0: 226, 1: 22})
# ****************************************************************************************************
# LABEL ENCODING OF: appetite
# Counter({'good': 167, 'poor': 81})
# Counter({0: 167, 1: 81})
# ****************************************************************************************************
# LABEL ENCODING OF: pedal_edema
# Counter({'no': 173, 'yes': 75})
# Counter({0: 173, 1: 75})
# ****************************************************************************************************
# LABEL ENCODING OF: albumin
# Counter({0: 93, 1: 44, 2: 43, 3: 43, 4: 24, 5: 1})
# Counter({0: 93, 1: 44, 2: 43, 3: 43, 4: 24, 5: 1})
# ****************************************************************************************************
# LABEL ENCODING OF: pus_cell_clumps
# Counter({'notpresent': 207, 'present': 41})
# Counter({0: 207, 1: 41})
# ****************************************************************************************************
# LABEL ENCODING OF: coronary_artery_disease
# Counter({'no': 215, 'yes': 33})
# Counter({0: 215, 1: 33})
# ****************************************************************************************************
# LABEL ENCODING OF: anemia
# Counter({'no': 189, 'yes': 59})
# Counter({0: 189, 1: 59})
# ****************************************************************************************************
# LABEL ENCODING OF: pus_cell
# Counter({'normal': 172, 'abnormal': 76})
# Counter({1: 172, 0: 76})
# ****************************************************************************************************
# LABEL ENCODING OF: specific_gravity
# Counter({1.01: 84, 1.015: 75, 1.02: 51, 1.025: 31, 1.005: 7})
# Counter({1: 84, 2: 75, 3: 51, 4: 31, 0: 7})
# ****************************************************************************************************
# LABEL ENCODING OF: diabetesmellitus
# Counter({'yes': 135, 'no': 113})
# Counter({1: 135, 0: 113})
# ****************************************************************************************************
# LABEL ENCODING OF: hypertension
# Counter({'yes': 145, 'no': 103})
# Counter({1: 145, 0: 103})
# ****************************************************************************************************

# %%
data
# Out:
#      age  blood_pressure  specific_gravity  albumin  sugar  red_blood_cells  \
# 0     48              80                 3        1      0                1
# 1      7              50                 3        4      0                1
# 2     62              80                 1        2      3                1
# 3     48              70                 0        4      0                1
# 4     51              80                 1        2      0                1
# ..   ...             ...               ...      ...    ...              ...
# 243   23              80                 4        0      0                1
# 244   45              60                 4        0      0                1
# 245   57              80                 3        0      0                1
# 246   51              80                 3        0      0                1
# 247   34              60                 4        0      0                1
#
#      pus_cell  pus_cell_clumps  bacteria  blood glucose random  ...  \
# 0           1                0         0                   121  ...
# 1           1                0         0                   423  ...
# 2           1                0         0                   117  ...
# 3           0                1         0                   106  ...
# 4           1                0         0                    74  ...
# ..        ...              ...       ...                   ...  ...
# 243         1                0         0                   123  ...
# 244         1                1         0                   100  ...
# 245         1                0         0                    94  ...
# 246         1                1         0                    81  ...
# 247         1                0         0                   124  ...
#
#      packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# 0                  44.0                  7800.0                   5.2
# 1                  38.0                  6000.0                   3.9
# 2                  31.0                  7500.0                   4.6
# 3                  32.0                  6700.0                   4.4
# 4                  35.0                  7300.0                   5.0
# ..                  ...                     ...                   ...
# 243                44.0                  7300.0                   4.9
# 244                45.0                  9400.0                   6.4
# 245                48.0                  9600.0                   5.6
# 246                52.0                  9900.0                   5.2
# 247                41.0                  7000.0                   4.8
#
#      hypertension  diabetesmellitus  coronary_artery_disease  appetite  \
# 0               1                 1                        0         0
# 1               0                 0                        0         0
# 2               0                 1                        0         1
# 3               1                 0                        0         1
# 4               0                 0                        0         0
# ..            ...               ...                      ...       ...
# 243             1                 0                        0         0
# 244             1                 1                        0         0
# 245             1                 0                        1         1
# 246             1                 0                        1         0
# 247             0                 0                        0         1
#
#      pedal_edema  anemia  class
# 0              0       0      0
# 1              0       0      0
# 2              0       1      0
# 3              1       1      0
# 4              0       0      0
# ..           ...     ...    ...
# 243            0       0      0
# 244            0       1      0
# 245            0       0      0
# 246            0       1      0
# 247            1       1      0
#
# [248 rows x 25 columns]

# %%
x=data.iloc[:,0:25]
y=data.iloc[:,24]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)#train test split
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (198, 25)
# (198,)
# (50, 25)
# (50,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)#train test split
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
unique_classes = y_train.unique()
print(unique_classes)
# Out:
# (198, 25)
# (198,)
# (50, 25)
# (50,)
# [0]

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
from sklearn.linear_model import LogisticRegression
lgr = LogisticRegression()
lgr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 3
#       1 from sklearn.linear_model import LogisticRegression
#       2 lgr = LogisticRegression()
# ----> 3 lgr.fit(x_train,y_train)
#
# File c:\Users\Saptarshi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Saptarshi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1201, in LogisticRegression.fit(self, X, y, sample_weight)
#    1198 else:
#    1199     _dtype = [np.float64, np.float32]
# -> 1201 X, y = self._validate_data(
#    1202     X,
#    1203     y,
#    1204     accept_sparse="csr",
#    1205     dtype=_dtype,
#    1206     order="C",
#    1207     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1208 )
#    1209 check_classification_targets(y)
#    1210 self.classes_ = np.unique(y)
#
# File c:\Users\Saptarshi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\Saptarshi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1281, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    (...)
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1281 check_consistent_length(X, y)
#    1283 return X, y
#
# File c:\Users\Saptarshi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [198, 199]

# %%
y_pred = lgr.predict(x_test)

print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 y_pred = lgr.predict(x_test)
#       3 print(y_pred)
#
# File c:\Users\Saptarshi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:351, in LinearClassifierMixin.predict(self, X)
#     337 """
#     338 Predict class labels for samples in X.
#     339
#    (...)
#     348     Vector containing the class labels for each sample.
#     349 """
#     350 xp, _ = get_namespace(X)
# --> 351 scores = self.decision_function(X)
#     352 if len(scores.shape) == 1:
#     353     indices = xp.astype(scores > 0, int)
#
# File c:\Users\Saptarshi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:333, in LinearClassifierMixin.decision_function(self, X)
#     330 xp, _ = get_namespace(X)
#     332 X = self._validate_data(X, accept_sparse="csr", reset=False)
# --> 333 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     334 return xp.reshape(scores, (-1,)) if scores.shape[1] == 1 else scores
#
# AttributeError: 'LogisticRegression' object has no attribute 'coef_'

# %%
from sklearn.metrics import r2_score
acc= r2_score(y_pred,y_test)
acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 from sklearn.metrics import r2_score
# ----> 2 acc= r2_score(y_pred,y_test)
#       3 acc
#
# NameError: name 'y_pred' is not defined

# %%
import pickle
pickle.dump(lgr,open('CKD.pkl','wb'))

# %%
conf_mat = confusion_matrix(y_test,y_pred)
conf_mat
# Out:
# array([[51,  3],
#        [ 1, 25]])

# %%
x_train.shape
# Out:
# (320, 25)

# %%
data.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood glucose random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'hemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetesmellitus', 'coronary_artery_disease', 'appetite',
#        'pedal_edema', 'anemia', 'class'],
#       dtype='object')
